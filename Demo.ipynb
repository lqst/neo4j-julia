# %%
using Pkg;
Pkg.instantiate()

# %%
Pkg.add("Plots")
Pkg.add("PyCall")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %%
using Plots
plot(sin, -2π, 2π, label="sin(x)")

# %%
using PyCall
pd = pyimport("pandas")
graphdatascience = pyimport("graphdatascience")
# Out:
# PyObject <module 'graphdatascience' from '/home/haklof/.local/lib/python3.10/site-packages/graphdatascience/__init__.py'>

# %%
gds = graphdatascience.GraphDataScience("neo4j://localhost:7687", auth=("neo4j", "test1234"))
gds.version()
# Out:
# "2.2.2"
